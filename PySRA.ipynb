# %%
import pandas as pd
import numpy as np
import pysradb
from pysradb.sraweb import SRAweb
from joblib import Parallel, delayed

# %%
db = SRAweb()

# %%
df = db.sra_metadata('SRP057500', detailed = True)
df
# Out:
#     run_accession study_accession experiment_accession  \
# 0      SRR2096520       SRP057500           SRX1091636
# 1      SRR2096519       SRP057500           SRX1091635
# 2      SRR2096518       SRP057500           SRX1091634
# 3      SRR2096517       SRP057500           SRX1091633
# 4      SRR2096516       SRP057500           SRX1091632
# ..            ...             ...                  ...
# 285    SRR1982588       SRP057500           SRX1001494
# 286    SRR1982587       SRP057500           SRX1001493
# 287    SRR1982586       SRP057500           SRX1001492
# 288    SRR1982585       SRP057500           SRX1001491
# 289    SRR1982584       SRP057500           SRX1001490
#
#                                       experiment_title  \
# 0    GSM1817132: Blood_Platelets_Lung-L65; Homo sap...
# 1    GSM1817131: Blood_Platelets_Lung-L59; Homo sap...
# 2    GSM1817130: Blood_Platelets_Lung-L58; Homo sap...
# 3    GSM1817129: Blood_Platelets_Lung-L51; Homo sap...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   run_accession          290 non-null    object
#  1   study_accession        290 non-null    object
#  2   experiment_accession   290 non-null    object
#  3   experiment_title       290 non-null    object
#  4   experiment_desc        290 non-null    object
#  5   organism_taxid         290 non-null    object
#  6   organism_name          290 non-null    object
#  7   library_name           0 non-null      object
#  8   library_strategy       290 non-null    object
#  9   library_source         290 non-null    object
#  10  library_selection      290 non-null    object
#  11  library_layout         290 non-null    object
#  12  sample_accession       290 non-null    object
#  13  sample_title           0 non-null      object
# ...

# %%
db.download(df=df, skip_confirmation=True)
# Out:
# The supplied url column "None" cannot be found.
#
# Using recommended_url instead.
#
# Checking download URLs
# The download URL:  https://sra-downloadb.st-va.ncbi.nlm.nih.gov/sos2/sra-pub-run-4/SRR2096520/SRR2096520.1  is likely invalid.
# Removing SRR2096520 from the download list
#
# The download URL:  https://sra-downloadb.st-va.ncbi.nlm.nih.gov/sos2/sra-pub-run-4/SRR2096519/SRR2096519.1  is likely invalid.
# Removing SRR2096519 from the download list
#
# The download URL:  https://sra-downloadb.st-va.ncbi.nlm.nih.gov/sos2/sra-pub-run-4/SRR2096518/SRR2096518.1  is likely invalid.
# Removing SRR2096518 from the download list
#
# The download URL:  https://sra-downloadb.st-va.ncbi.nlm.nih.gov/sos2/sra-pub-run-4/SRR2096517/SRR2096517.1  is likely invalid.
# Removing SRR2096517 from the download list
#
# The download URL:  https://sra-downloadb.st-va.ncbi.nlm.nih.gov/sos2/sra-pub-run-4/SRR2096516/SRR2096516.1  is likely invalid.
# Removing SRR2096516 from the download list
#
# ...
